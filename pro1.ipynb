# %%
import pandas as pd

# %%
df = pd.read_csv("students(1).csv")

# %%
print(df)
# Out:
#    Student_ID   Name  Gender  Age  Math  Science  Marks
# 0         101   Ravi    Male   20    85       90     88
# 1         102  Priya  Female   21    78       82     80
# 2         103  Kumar    Male   22    92       88     90
# 3         104  Divya  Female   20    65       75     70
# 4         105   Arun    Male   23    80       85     82
# 5         106  Sneha  Female   21    88       91     89
# 6         107    Raj    Male   22    75       79     77
# 7         108  Meena  Female   20    90       94     92
# 8         109   Ajay    Male   24    72       70     71
# 9         110    Anu  Female   22    86       89     87

# %%
df.head()
# Out:
#    Student_ID   Name  Gender  Age  Math  Science  Marks
# 0         101   Ravi    Male   20    85       90     88
# 1         102  Priya  Female   21    78       82     80
# 2         103  Kumar    Male   22    92       88     90
# 3         104  Divya  Female   20    65       75     70
# 4         105   Arun    Male   23    80       85     82

# %%
df.shape
# Out:
# (10, 7)

# %%
print(df.dtypes)
# Out:
# Student_ID     int64
# Name          object
# Gender        object
# Age            int64
# Math           int64
# Science        int64
# Marks          int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  10 non-null     int64
#  1   Name        10 non-null     object
#  2   Gender      10 non-null     object
#  3   Age         10 non-null     int64
#  4   Math        10 non-null     int64
#  5   Science     10 non-null     int64
#  6   Marks       10 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 688.0+ bytes

# %%
df.describe()
# Out:
#        Student_ID        Age       Math    Science      Marks
# count    10.00000  10.000000  10.000000  10.000000  10.000000
# mean    105.50000  21.500000  81.100000  84.300000  82.600000
# std       3.02765   1.354006   8.659613   7.689098   7.919035
# min     101.00000  20.000000  65.000000  70.000000  70.000000
# 25%     103.25000  20.250000  75.750000  79.750000  77.750000
# 50%     105.50000  21.500000  82.500000  86.500000  84.500000
# 75%     107.75000  22.000000  87.500000  89.750000  88.750000
# max     110.00000  24.000000  92.000000  94.000000  92.000000

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Gender', 'Age', 'Math', 'Science', 'Marks'], dtype='object')

# %%
for col in df.columns:
    print(col, df[col].dtype,df[col].nunique())
# Out:
# Student_ID int64 10
# Name object 10
# Gender object 2
# Age int64 5
# Math int64 10
# Science int64 10
# Marks int64 10

# %%
csvdata = pd.read_csv("students(1).csv")
exceldata =pd.read_excel("students.xlsx")
JSONdata = pd.read_json("students.json")

# %%
print(csvdata)
print(exceldata)
print(JSONdata)

merged = pd.concat([csvdata, exceldata, JSONdata], ignore_index=True)

print(merged)
# Out:
#    Student_ID   Name  Gender  Age  Math  Science  Marks
# 0         101   Ravi    Male   20    85       90     88
# 1         102  Priya  Female   21    78       82     80
# 2         103  Kumar    Male   22    92       88     90
# 3         104  Divya  Female   20    65       75     70
# 4         105   Arun    Male   23    80       85     82
# 5         106  Sneha  Female   21    88       91     89
# 6         107    Raj    Male   22    75       79     77
# 7         108  Meena  Female   20    90       94     92
# 8         109   Ajay    Male   24    72       70     71
# 9         110    Anu  Female   22    86       89     87
#    Student_ID   Name  Gender  Age  Math  Science  Marks
# 0         101   Ravi    Male   20    85       90     88
# 1         102  Priya  Female   21    78       82     80
# 2         103  Kumar    Male   22    92       88     90
# 3         104  Divya  Female   20    65       75     70
# 4         105   Arun    Male   23    80       85     82
# ...

# %%
print(df.isnull().sum())
# Out:
# Student_ID    0
# Name          0
# Gender        0
# Age           0
# Math          0
# Science       0
# Marks         0
# dtype: int64

# %%
print('total Missing:', df.isnull().sum().sum())
# Out:
# total Missing: 0

# %%
df['marks']=df['Marks'].fillna(df['Marks'].mean())
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df =df.drop_duplicates()

# %%
df['Name'] = df['Name'].str.strip()

print(df.head())
# Out:
#    Student_ID   Name  Gender  Age  Math  Science  Marks  marks
# 0         101   Ravi    Male   20    85       90     88     88
# 1         102  Priya  Female   21    78       82     80     80
# 2         103  Kumar    Male   22    92       88     90     90
# 3         104  Divya  Female   20    65       75     70     70
# 4         105   Arun    Male   23    80       85     82     82

# %%
df['Total']= df['Math'] + df['Science']
print(df['Total'])
# Out:
# 0    175
# 1    160
# 2    180
# 3    140
# 4    165
# 5    179
# 6    154
# 7    184
# 8    142
# 9    175
# Name: Total, dtype: int64

# %%
print(df.head())
# Out:
#    Student_ID   Name  Gender  Age  Math  Science  Marks  marks  Total
# 0         101   Ravi    Male   20    85       90     88     88    175
# 1         102  Priya  Female   21    78       82     80     80    160
# 2         103  Kumar    Male   22    92       88     90     90    180
# 3         104  Divya  Female   20    65       75     70     70    140
# 4         105   Arun    Male   23    80       85     82     82    165

# %%
df['Marks_Normalized'] = ((df['Marks'] - df['Marks'].min()) /
    (df['Marks'].max() - df['Marks'].min()))

print(df.head())
# Out:
#    Student_ID   Name  Gender  Age  Math  Science  Marks  marks  Total  \
# 0         101   Ravi    Male   20    85       90     88     88    175
# 1         102  Priya  Female   21    78       82     80     80    160
# 2         103  Kumar    Male   22    92       88     90     90    180
# 3         104  Divya  Female   20    65       75     70     70    140
# 4         105   Arun    Male   23    80       85     82     82    165
#
#    Marks_Normalized
# 0          0.818182
# 1          0.454545
# 2          0.909091
# 3          0.000000
# 4          0.545455

# %%
print("Mean:",df['Marks'].mean())
print("Median:",df['Marks'].median())
print("Mode:",df['Marks'].mode())
print("Mean:",df['Marks'].mean())
print("std dev:",df['Marks'].std())
# Out:
# Mean: 82.6
# Median: 84.5
# Mode: 0    70
# 1    71
# 2    77
# 3    80
# 4    82
# 5    87
# 6    88
# 7    89
# 8    90
# 9    92
# Name: Marks, dtype: int64
# Mean: 82.6
# std dev: 7.919034733546198

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Marks'])
plt.title('Distribution of Marks')
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.show()

# %%
df['Gender'].value_counts().plot(kind='bar')
plt.title('Count by Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.boxplot(df['Marks'])
plt.title('Box plot of Marks')
plt.ylabel('value')
plt.show()

# %%
print(df.corr(numeric_only=True))
# Out:
#                   Student_ID       Age      Math   Science     Marks  \
# Student_ID          1.000000  0.447214 -0.010595 -0.107389 -0.078782
# Age                 0.447214  1.000000 -0.156359 -0.474921 -0.331600
# Math               -0.010595 -0.156359  1.000000  0.895602  0.976049
# Science            -0.107389 -0.474921  0.895602  1.000000  0.969322
# Marks              -0.078782 -0.331600  0.976049  0.969322  1.000000
# marks              -0.078782 -0.331600  0.976049  0.969322  1.000000
# Total              -0.057638 -0.314472  0.976639  0.970274  0.999219
# Marks_Normalized   -0.078782 -0.331600  0.976049  0.969322  1.000000
#
#                      marks     Total  Marks_Normalized
# Student_ID       -0.078782 -0.057638         -0.078782
# Age              -0.331600 -0.314472         -0.331600
# Math              0.976049  0.976639          0.976049
# Science           0.969322  0.970274          0.969322
# Marks             1.000000  0.999219          1.000000
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.title('Correlation Heat Map')
plt.show()
